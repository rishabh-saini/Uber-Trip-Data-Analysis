# %%
# %pylab inline
import pandas as pd
import numpy as np
import seaborn
from numpy.random import randint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load csv file into memory

# %%
data=pd.read_csv("uber-raw-data-apr14.csv")

# %%
data#prints first five datas
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1         4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2         4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3         4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4         4/1/2014 0:33:00  40.7594 -73.9722  B02512
# 5         4/1/2014 0:33:00  40.7383 -74.0403  B02512
# 6         4/1/2014 0:39:00  40.7223 -73.9887  B02512
# 7         4/1/2014 0:45:00  40.7620 -73.9790  B02512
# 8         4/1/2014 0:55:00  40.7524 -73.9960  B02512
# 9         4/1/2014 1:01:00  40.7575 -73.9846  B02512
# 10        4/1/2014 1:19:00  40.7256 -73.9869  B02512
# 11        4/1/2014 1:48:00  40.7591 -73.9684  B02512
# 12        4/1/2014 1:49:00  40.7271 -73.9803  B02512
# 13        4/1/2014 2:11:00  40.6463 -73.7896  B02512
# 14        4/1/2014 2:25:00  40.7564 -73.9167  B02512
# 15        4/1/2014 2:31:00  40.7666 -73.9531  B02512
# 16        4/1/2014 2:43:00  40.7580 -73.9761  B02512
# ...

# %%
data1=pd.read_csv("uber-raw-data-may14.csv")

# %%
data1
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         5/1/2014 0:02:00  40.7521 -73.9914  B02512
# 1         5/1/2014 0:06:00  40.6965 -73.9715  B02512
# 2         5/1/2014 0:15:00  40.7464 -73.9838  B02512
# 3         5/1/2014 0:17:00  40.7463 -74.0011  B02512
# 4         5/1/2014 0:17:00  40.7594 -73.9734  B02512
# 5         5/1/2014 0:20:00  40.7685 -73.8625  B02512
# 6         5/1/2014 0:21:00  40.7637 -73.9962  B02512
# 7         5/1/2014 0:21:00  40.7252 -74.0023  B02512
# 8         5/1/2014 0:25:00  40.7607 -73.9625  B02512
# 9         5/1/2014 0:25:00  40.7212 -73.9879  B02512
# 10        5/1/2014 0:29:00  40.7255 -73.9986  B02512
# 11        5/1/2014 0:32:00  40.6467 -73.7901  B02512
# 12        5/1/2014 0:40:00  40.7613 -73.9788  B02512
# 13        5/1/2014 0:56:00  40.7807 -73.9497  B02512
# 14        5/1/2014 1:00:00  40.7585 -73.9708  B02512
# 15        5/1/2014 1:02:00  40.7163 -73.9895  B02512
# 16        5/1/2014 1:06:00  40.7265 -73.9958  B02512
# ...

# %%
data2=pd.read_csv("uber-raw-data-jul14.csv")
data2
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         7/1/2014 0:03:00  40.7586 -73.9706  B02512
# 1         7/1/2014 0:05:00  40.7605 -73.9994  B02512
# 2         7/1/2014 0:06:00  40.7320 -73.9999  B02512
# 3         7/1/2014 0:09:00  40.7635 -73.9793  B02512
# 4         7/1/2014 0:20:00  40.7204 -74.0047  B02512
# 5         7/1/2014 0:35:00  40.7487 -73.9869  B02512
# 6         7/1/2014 0:57:00  40.7444 -73.9961  B02512
# 7         7/1/2014 0:58:00  40.7132 -73.9492  B02512
# 8         7/1/2014 1:04:00  40.7590 -73.9730  B02512
# 9         7/1/2014 1:08:00  40.7601 -73.9823  B02512
# 10        7/1/2014 1:12:00  40.6951 -74.1784  B02512
# 11        7/1/2014 1:23:00  40.7203 -73.9992  B02512
# 12        7/1/2014 1:45:00  40.7575 -73.9721  B02512
# 13        7/1/2014 2:07:00  40.7471 -73.9872  B02512
# 14        7/1/2014 2:48:00  40.7808 -73.9565  B02512
# 15        7/1/2014 3:11:00  40.7624 -73.9786  B02512
# 16        7/1/2014 3:14:00  40.8150 -73.9095  B02512
# ...

# %%
data3=pd.read_csv("uber-raw-data-aug14.csv")
data3
# Out:
#                  Date/Time      Lat      Lon    Base
# 0         8/1/2014 0:03:00  40.7366 -73.9906  B02512
# 1         8/1/2014 0:09:00  40.7260 -73.9918  B02512
# 2         8/1/2014 0:12:00  40.7209 -74.0507  B02512
# 3         8/1/2014 0:12:00  40.7387 -73.9856  B02512
# 4         8/1/2014 0:12:00  40.7323 -74.0077  B02512
# 5         8/1/2014 0:13:00  40.7349 -74.0033  B02512
# 6         8/1/2014 0:15:00  40.7279 -73.9542  B02512
# 7         8/1/2014 0:17:00  40.7210 -73.9937  B02512
# 8         8/1/2014 0:19:00  40.7195 -74.0060  B02512
# 9         8/1/2014 0:20:00  40.7448 -73.9799  B02512
# 10        8/1/2014 0:21:00  40.7399 -74.0057  B02512
# 11        8/1/2014 0:25:00  40.7651 -73.9683  B02512
# 12        8/1/2014 0:27:00  40.7354 -74.0081  B02512
# 13        8/1/2014 0:29:00  40.7339 -74.0028  B02512
# 14        8/1/2014 0:29:00  40.7364 -74.0301  B02512
# 15        8/1/2014 0:29:00  40.7364 -74.0301  B02512
# 16        8/1/2014 0:30:00  40.7252 -73.9516  B02512
# ...

# %% [markdown]
# # Daily income in the month of April

# %%
d1=data.iloc[1:9]

d2=data.iloc[2000:2009]

d3=data.iloc[3000:3009]
d4=data.iloc[5466:5475]#prints last five datas
d5=data.iloc[6000:6009]
d6=data.iloc[7000:7009]
d7=data.iloc[8000:8009]
d8=data.iloc[10000:10009]
d9=data.iloc[12000:12009]
d10=data.iloc[23000:23009]
d11=data.iloc[35000:35009]
d12=data.iloc[47000:47009]
d13=data.iloc[55000:55009]
d14=data.iloc[60000:60009]
d15=data.iloc[70000:70009]
d16=data.iloc[80000:80009]
d17=data.iloc[92000:92009]
d18=data.iloc[100000:100009]
d19=data.iloc[200000:200009]
d20=data.iloc[300000:300009]
d21=data.iloc[400000:400009]
d22=data.iloc[500000:500009]
d23=data.iloc[502000:502009]
d24=data.iloc[508000:508009]
d25=data.iloc[510000:510009]
d26=data.iloc[530000:530009]
d27=data.iloc[550000:550009]
d28=data.iloc[556000:566009]
d29=data.iloc[560000:560011]
d30=data.iloc[564486:564495]

# %%
 def get_dataApril():
    choice=input("Uber Trip Data Analysis for month of April :")
    if choice=='1':
        print(d1)
    elif choice == '2':
        print(d2)
    elif choice == '3':
        print(d3)
    elif choice == '4':
        print(d4)
    elif choice == '5':
        print(d5)
    elif choice == '6':
        print(d6)
    elif choice == '7':
        print(d7)
    elif choice == '8':
        print(d8)
    elif choice == '9':
        print(d9)
    elif choice == '10':
        print(d10)
    elif choice == '11':
        print(d11)
    elif choice == '12':
        print(d12)
    elif choice=='13':
        print(d13)
    elif choice == '14':
        print(d14)
    elif choice == '15':
        print(d15)
    elif choice == '16':
        print(d16)
    elif choice == '17':
        print(d17)
    elif choice == '18':
        print(d18)
    elif choice == '19':
        print(d19)
    elif choice == '20':
        print(d20)
    elif choice == '21':
        print(d21)
    elif choice == '22':
        print(d22)
    elif choice == '23':
        print(d23)
    elif choice == '24':
        print(d24)
    elif choice=='25':
        print(d25)
    elif choice == '26':
        print(d26)
    elif choice == '27':
        print(d27)
    elif choice == '28':
        print(d28)
    elif choice == '29':
        print(d29)
    elif choice == '30':
        print(d30)
    else:
        print("***Wrong Input***")
get_dataApril()
# Out:
# Uber Trip Data Analysis for month of April :10
#                Date/Time      Lat      Lon    Base
# 23000  4/21/2014 7:08:00  40.7480 -73.9807  B02512
# 23001  4/21/2014 7:09:00  40.7721 -73.9501  B02512
# 23002  4/21/2014 7:09:00  40.7420 -73.9964  B02512
# 23003  4/21/2014 7:09:00  40.7420 -73.9964  B02512
# 23004  4/21/2014 7:10:00  40.7871 -73.9681  B02512
# 23005  4/21/2014 7:11:00  40.7714 -73.9899  B02512
# 23006  4/21/2014 7:12:00  40.7236 -74.0367  B02512
# 23007  4/21/2014 7:16:00  40.7199 -74.0078  B02512
# 23008  4/21/2014 7:17:00  40.7725 -73.9612  B02512

# %%
data['Date/Time']=data['Date/Time'].map(pd.to_datetime)

# %%
def get_dom1(dt):
        return dt.day
data['dom']=data['Date/Time'].map(get_dom1)   ##creating new column


def get_weekday1(dt):
        return dt.weekday()
data['weekday']=data['Date/Time'].map(get_weekday1)  


def get_hour1(dt):
        return dt.hour
data['hour']=data['Date/Time'].map(get_hour1)  
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  weekday  hour
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30        2    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30        2    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30        2    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30        2    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30        2    23

# %%
import numpy as np
import pandas as pd
import matplotlib
from numpy.random import randint
    

def april():
    
    print("Uber Trip Data For Month April")
    print("A- Date Of Month")
    print("B- Weekday")
    print("C- Hour")
    a1=input("Enter Choice: ")
    if a1== 'A':
        hist(data.dom,bins=30,rwidth=0.8,range=(0.5,30.5))
        xlabel('date of month')
        ylabel('frequency')
        title('Frequency by Date Of Month - uber trip April 2014')
    elif a1=='B':
            hist(data.weekday,bins=7,rwidth=0.8,range=(-.5,6))
            xticks (range(7),'mon tues wed thur fri sat sun'.split())
            xlabel('weekdays')
            ylabel('frequency')
            title('Frequency by Weekday - uber trip April 2014')
    elif a1=='C':
                hist(data.hour,bins=24,rwidth=0.8,range=(0.5,24.5))
                xlabel('hours')
                ylabel('frequency')
                title('Frequency by Hours - uber trip April 2014')
    else:
                    print("***Wrong Input***")
april()   

df=pd.DataFrame(np.random.randint(1,440,4),index='week1 week2 week3 week4 '.split(),columns='Fare'.split())
print(df)
print("Average fair for the month ")
print(df.mean())
matplotlib.style.use('dark_background')
df.plot.bar(figsize=(10,6),width=0.5,color='lightgreen',edgecolor='yellow',linewidth=1)        
title('Weekly income chart')
# Out:
# Uber Trip Data For Month April
# A- Date Of Month
# B- Weekday
# C- Hour
# Enter Choice: A
#        Fare
# week1   369
# week2   302
# week3   247
# week4   183
# Average fair for the month
# Fare    275.25
# dtype: float64
# Text(0.5, 1.0, 'Weekly income chart')

# %% [markdown]
# # Daily income in the month of May

# %%
dd1=data1.iloc[1:9]
dd2=data1.iloc[2000:20009]
dd3=data1.iloc[3000:3009]
dd4=data1.iloc[4660:4669]#prints last five datas
dd5=data1.iloc[6000:6009]
dd6=data1.iloc[7009:7009]
dd7=data1.iloc[8000:8009]
dd8=data1.iloc[10000:10009]
dd9=data1.iloc[11000:11009]
dd10=data1.iloc[12000:12009]
dd11=data1.iloc[35000:35009]
dd12=data1.iloc[47000:47009]
dd13=data1.iloc[55000:55009]
dd14=data1.iloc[60000:60009]
dd15=data1.iloc[70000:70009]
dd16=data1.iloc[80000:80009]
dd17=data1.iloc[92000:92009]
dd18=data1.iloc[100000:10009]
dd19=data1.iloc[200000:200009]
dd20=data1.iloc[300000:300009]
dd21=data1.iloc[400000:400009]
dd22=data1.iloc[500000:500009]
dd23=data1.iloc[502000:502009]
dd24=data1.iloc[508000:508009]
dd25=data1.iloc[510000:510009]
dd26=data1.iloc[530000:530009]
dd27=data1.iloc[550000:550009]
dd28=data1.iloc[656000:666009]
dd29=data1.iloc[760000:760011]
dd30=data1.iloc[864486:864495]
dd31=data1.iloc[1048569:1048575]

# %%
def get_dataMay():
    choice=input("Uber Trip Data Analysis for month of May :")
    if choice=='1':
        print(dd1)
    elif choice == '2':
        print(dd2)
    elif choice == '3':
        print(dd3)
    elif choice == '4':
        print(dd4)
    elif choice == '5':
        print(dd5)
    elif choice == '6':
        print(dd6)
    if choice=='7':
        print(dd7)
    elif choice == '8':
        print(dd8)
    elif choice == '9':
        print(dd9)
    elif choice == '10':
        print(dd10)
    elif choice == '11':
        print(dd11)
    elif choice == '12':
        print(dd12)
    elif choice=='13':
        print(dd13)
    elif choice == '14':
        print(dd14)
    elif choice == '15':
        print(dd15)
    elif choice == '16':
        print(dd16)
    elif choice == '17':
        print(dd17)
    elif choice == '18':
        print(dd18)
    elif choice=='19':
        print(dd19)
    elif choice == '20':
        print(dd20)
    elif choice == '21':
        print(dd21)
    elif choice == '22':
        print(dd22)
    elif choice == '23':
        print(dd23)
    elif choice == '24':
        print(dd24)
    elif choice=='25':
        print(dd25)
    elif choice == '26':
        print(dd26)
    elif choice == '27':
        print(dd27)
    elif choice == '28':
        print(dd28)
    elif choice == '29':
        print(dd29)
    elif choice == '30':
        print(dd30)
    elif choice == '31':
        print(dd31)    
    else:
        print("***Wrong Input***")
get_dataMay()
# Out:
# Uber Trip Data Analysis for month of May :15
#               Date/Time      Lat      Lon    Base
# 70000  5/5/2014 6:49:00  40.7419 -74.0047  B02598
# 70001  5/5/2014 6:49:00  40.7193 -74.0037  B02598
# 70002  5/5/2014 6:49:00  40.7269 -73.9466  B02598
# 70003  5/5/2014 6:49:00  40.7343 -73.9935  B02598
# 70004  5/5/2014 6:49:00  40.7675 -73.9897  B02598
# 70005  5/5/2014 6:49:00  40.7377 -74.0019  B02598
# 70006  5/5/2014 6:49:00  40.7705 -73.8653  B02598
# 70007  5/5/2014 6:49:00  40.7708 -73.9538  B02598
# 70008  5/5/2014 6:49:00  40.7647 -73.9662  B02598

# %%
data1['Date/Time']=data1['Date/Time'].map(pd.to_datetime)

# %%
def get_dom2(dt):
        return dt.day
data1['dom']=data1['Date/Time'].map(get_dom2)   ##creating new column


def get_weekday2(dt):
        return dt.weekday()
data1['weekday']=data1['Date/Time'].map(get_weekday2)  


def get_hour1(dt):
        return dt.hour
data1['hour']=data1['Date/Time'].map(get_hour2)  
data1.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f2d9d19d474e> in <module>
#      11 def get_hour1(dt):
#      12         return dt.hour
# ---> 13 data1['hour']=data1['Date/Time'].map(get_hour2)
#      14 data1.tail()
#
# NameError: name 'get_hour2' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib
from numpy.random import randint
def may():
    print("Uber Trip Data For Month May")
    print("A- Date Of Month")
    print("B- Weekday")
    print("C- Hour")
    C=input("Enter Choice: ")
    if C== 'A':
        hist(data1.dom,bins=30,rwidth=0.8,range=(0.5,30.5))
        xlabel('date of month')
        ylabel('frequency')
        title('Frequency by Date Of Month - uber trip May 2014')
    elif C=='B':
            hist(data1.weekday,bins=7,rwidth=0.8,range=(-.5,6))
            xticks (range(7),'mon tues wed thur fri sat sun'.split())
            xlabel('weekdays')
            ylabel('frequency')
            title('Frequency by Weekday - uber trip May 2014')
    elif C=='C':
                hist(data1.hour,bins=24,rwidth=0.8,range=(0.5,24.5))
                xlabel('hours')
                ylabel('frequency')
                title('Frequency by Hours - uber trip May 2014')
    else:
                    print("***Wrong Input***")
may()

df1=pd.DataFrame(np.random.randint(1,440,4),index='week1 week2 week3 week4 '.split(),columns='Fare'.split())
print(df1)
print("Average fair for the month ")
print(df1.mean())
matplotlib.style.use('grayscale')
df1.plot.bar(figsize=(12,7),width=0.7,color='yellow',edgecolor='lightgreen',linewidth=1)        
title('Weekly income chart')
# Out:
# Uber Trip Data For Month May
# A- Date Of Month
# B- Weekday
# C- Hour
# Enter Choice: B
#        Fare
# week1   162
# week2   158
# week3   425
# week4   231
# Average fair for the month
# Fare    244.0
# dtype: float64
# Text(0.5, 1.0, 'Weekly income chart')

# %%
matplotlib.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# # Daily income in the month of July

# %%
D1=data2.iloc[1:9]
D2=data2.iloc[2000:2009]
D3=data2.iloc[3000:3009]
D4=data2.iloc[5466:5475]#prints last five datas
D5=data2.iloc[6000:6009]
D6=data2.iloc[7000:7009]
D7=data2.iloc[8000:8009]
D8=data2.iloc[10000:10009]
D9=data2.iloc[12000:12009]
D10=data2.iloc[23000:23009]
D11=data2.iloc[35000:35009]
D12=data2.iloc[47000:47009]
D13=data2.iloc[55000:55009]
D14=data2.iloc[60000:60009]
D15=data2.iloc[70000:70009]
D16=data2.iloc[80000:80009]
D17=data2.iloc[92000:92009]
D18=data2.iloc[100000:100009]
D19=data2.iloc[200000:200009]
D20=data2.iloc[300000:300009]
D21=data2.iloc[400000:400009]
D22=data2.iloc[500000:500009]
D23=data2.iloc[502000:502009]
D24=data2.iloc[508000:508009]
D25=data2.iloc[510000:510009]
D26=data2.iloc[530000:530009]
D27=data2.iloc[550000:550009]
D28=data2.iloc[556000:566009]
D29=data2.iloc[560000:560011]
D30=data2.iloc[564486:564495]
D31=data2.iloc[796110:796119]

# %%
def get_dataJuly():
    choice=input("Uber Trip Data Analysis for month of July :")
    if choice=='1':
        print(D1)
    elif choice == '2':
        print(D2)
    elif choice == '3':
        print(D3)
    elif choice == '4':
        print(D4)
    elif choice == '5':
        print(D5)
    elif choice == '6':
        print(D6)
    if choice=='7':
        print(D7)
    elif choice == '8':
        print(D8)
    elif choice == '9':
        print(D9)
    elif choice == '10':
        print(D10)
    elif choice == '11':
        print(D11)
    elif choice == '12':
        print(D12)
    elif choice=='13':
        print(D13)
    elif choice == '14':
        print(D14)
    elif choice == '15':
        print(D15)
    elif choice == '16':
        print(D16)
    elif choice == '17':
        print(D17)
    elif choice == '18':
        print(D18)
    elif choice=='19':
        print(D19)
    elif choice == '20':
        print(D20)
    elif choice == '21':
        print(D21)
    elif choice == '22':
        print(D22)
    elif choice == '23':
        print(D23)
    elif choice == '24':
        print(D24)
    elif choice=='25':
        print(D25)
    elif choice == '26':
        print(D26)
    elif choice == '27':
        print(D27)
    elif choice == '28':
        print(D28)
    elif choice == '29':
        print(D29)
    elif choice == '30':
        print(D30)
    elif choice == '31':
        print(D31)    
    else:
        print("***Wrong Input***")
get_dataJuly()
# Out:
# Uber Trip Data Analysis for month of July :12
#                Date/Time      Lat      Lon    Base
# 47000  7/2/2014 17:02:00  40.7665 -73.9783  B02598
# 47001  7/2/2014 17:02:00  40.7564 -73.9754  B02598
# 47002  7/2/2014 17:02:00  40.7559 -73.9728  B02598
# 47003  7/2/2014 17:02:00  40.7559 -73.9728  B02598
# 47004  7/2/2014 17:02:00  40.7420 -73.9907  B02598
# 47005  7/2/2014 17:02:00  40.7407 -73.9982  B02598
# 47006  7/2/2014 17:02:00  40.7693 -73.9819  B02598
# 47007  7/2/2014 17:02:00  40.6612 -73.7914  B02598
# 47008  7/2/2014 17:02:00  40.7611 -73.9811  B02598

# %%
data2['Date/Time']=data2['Date/Time'].map(pd.to_datetime)

# %%
def get_dom3(dt):
        return dt.day
data2['dom']=data2['Date/Time'].map(get_dom3)   ##creating new column


def get_weekday3(dt):
        return dt.weekday()
data2['weekday']=data2['Date/Time'].map(get_weekday3)  


def get_hour3(dt):
        return dt.hour
data2['hour']=data2['Date/Time'].map(get_hour3)  
data2.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  weekday  hour
# 796116 2014-07-31 23:22:00  40.7285 -73.9846  B02764   31        3    23
# 796117 2014-07-31 23:23:00  40.7615 -73.9868  B02764   31        3    23
# 796118 2014-07-31 23:29:00  40.6770 -73.9515  B02764   31        3    23
# 796119 2014-07-31 23:30:00  40.7225 -74.0038  B02764   31        3    23
# 796120 2014-07-31 23:58:00  40.7199 -73.9884  B02764   31        3    23

# %%
import numpy as np
import pandas as pd
import matplotlib
from numpy.random import randint
def july():
    print("Uber Trip Data For Month July")
    print("A- Date Of Month")
    print("B- Weekday")
    print("C- Hour")
    o=input("Enter Choice: ")
    if o== 'A':
        hist(data2.dom,bins=30,rwidth=0.8,range=(0.5,30.5))
        xlabel('date of month')
        ylabel('frequency')
        title('Frequency by Date Of Month - uber trip July 2014')
    elif o=='B':
            hist(data2.weekday,bins=7,rwidth=0.8,range=(-.5,6))
            xticks (range(7),'mon tues wed thur fri sat sun'.split())
            xlabel('weekdays')
            ylabel('frequency')
            title('Frequency by Weekday - uber trip July 2014')
    elif o=='C':
                hist(data2.hour,bins=24,rwidth=0.8,range=(0.5,24.5))
                xlabel('hours')
                ylabel('frequency')
                title('Frequency by Hours - uber trip July 2014')
    else:
                    print("***Wrong Input***")
july()

df2=pd.DataFrame(np.random.randint(1,540,4),index='week1 week2 week3 week4 '.split(),columns='Fare'.split())
print(df2)
print("Average fair for the month ")
print(df2.mean())
matplotlib.style.use('grayscale')
df2.plot.bar(figsize=(12,7),width=0.7,color='yellow',edgecolor='lightgreen',linewidth=1)        
title('Weekly income chart')
# Out:
# Uber Trip Data For Month July
# A- Date Of Month
# B- Weekday
# C- Hour
# Enter Choice: C
#        Fare
# week1   194
# week2   268
# week3   238
# week4   101
# Average fair for the month
# Fare    200.25
# dtype: float64
# Text(0.5, 1.0, 'Weekly income chart')

# %% [markdown]
# # Daily income in the month of August

# %%
DD1=data2.iloc[1:9]
DD2=data2.iloc[2000:2009]
DD3=data2.iloc[3000:3009]
DD4=data2.iloc[5466:5475]#prints last five datas
DD5=data2.iloc[6000:6009]
DD6=data2.iloc[7000:7009]
DD7=data2.iloc[8000:8009]
DD8=data2.iloc[10000:10009]
DD9=data2.iloc[12000:12009]
DD10=data2.iloc[23000:23009]
DD11=data2.iloc[35000:35009]
DD12=data2.iloc[47000:47009]
DD13=data2.iloc[55000:55009]
DD14=data2.iloc[60000:60009]
DD15=data2.iloc[70000:70009]
DD16=data2.iloc[80000:80009]
DD17=data2.iloc[92000:92009]
DD18=data2.iloc[100000:100009]
DD19=data2.iloc[200000:200009]
DD20=data2.iloc[300000:300009]
DD21=data2.iloc[400000:400009]
DD22=data2.iloc[500000:500009]
DD23=data2.iloc[502000:502009]
DD24=data2.iloc[508000:508009]
DD25=data2.iloc[510000:510009]
DD26=data2.iloc[530000:530009]
DD27=data2.iloc[550000:550009]
DD28=data2.iloc[556000:566009]
DD29=data2.iloc[560000:560011]
DD30=data2.iloc[564486:564495]
DD31=data2.iloc[796110:796119]

# %%
def get_dataAug():
    choice=input("Uber Trip Data Analysis for month of August :")
    if choice=='1':
        print(DD1)
    elif choice == '2':
        print(DD2)
    elif choice == '3':
        print(DD3)
    elif choice == '4':
        print(DD4)
    elif choice == '5':
        print(DD5)
    elif choice == '6':
        print(DD6)
    if choice=='7':
        print(DD7)
    elif choice == '8':
        print(DD8)
    elif choice == '9':
        print(DD9)
    elif choice == '10':
        print(D10)
    elif choice == '11':
        print(D11)
    elif choice == '12':
        print(D12)
    elif choice=='13':
        print(D13)
    elif choice == '14':
        print(D14)
    elif choice == '15':
        print(D15)
    elif choice == '16':
        print(D16)
    elif choice == '17':
        print(D17)
    elif choice == '18':
        print(D18)
    elif choice=='19':
        print(D19)
    elif choice == '20':
        print(D20)
    elif choice == '21':
        print(D21)
    elif choice == '22':
        print(D22)
    elif choice == '23':
        print(D23)
    elif choice == '24':
        print(D24)
    elif choice=='25':
        print(D25)
    elif choice == '26':
        print(D26)
    elif choice == '27':
        print(D27)
    elif choice == '28':
        print(D28)
    elif choice == '29':
        print(D29)
    elif choice == '30':
        print(D30)
    elif choice == '31':
        print(D31)    
    else:
        print("***Wrong Input***")
get_dataAug()
# Out:
# Uber Trip Data Analysis for month of August :20
#                 Date/Time      Lat      Lon    Base
# 300000  7/3/2014 15:57:00  40.7212 -73.9879  B02617
# 300001  7/3/2014 15:58:00  40.7394 -73.9828  B02617
# 300002  7/3/2014 15:58:00  40.7516 -73.9821  B02617
# 300003  7/3/2014 15:58:00  40.7413 -73.9814  B02617
# 300004  7/3/2014 15:58:00  40.7566 -73.9906  B02617
# 300005  7/3/2014 15:59:00  40.7026 -73.9269  B02617
# 300006  7/3/2014 15:59:00  40.7435 -73.9852  B02617
# 300007  7/3/2014 15:59:00  40.7417 -74.0045  B02617
# 300008  7/3/2014 15:59:00  40.7589 -73.9725  B02617

# %%
data3['Date/Time']=data3['Date/Time'].map(pd.to_datetime)

# %%
def get_dom4(dt):
        return dt.day
data3['dom']=data3['Date/Time'].map(get_dom4)   ##creating new column


def get_weekday4(dt):
        return dt.weekday()
data3['weekday']=data3['Date/Time'].map(get_weekday4)  


def get_hour4(dt):
        return dt.hour
data3['hour']=data3['Date/Time'].map(get_hour4)  
data3.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  weekday  hour
# 829270 2014-08-31 23:55:00  40.7552 -73.9753  B02764   31        6    23
# 829271 2014-08-31 23:55:00  40.7552 -73.9753  B02764   31        6    23
# 829272 2014-08-31 23:55:00  40.7617 -73.9788  B02764   31        6    23
# 829273 2014-08-31 23:59:00  40.7395 -73.9889  B02764   31        6    23
# 829274 2014-08-31 23:59:00  40.7270 -73.9802  B02764   31        6    23

# %%
import numpy as np
import pandas as pd
import matplotlib
from numpy.random import randint
def aug():
    print("Uber Trip Data For Month July")
    print("A- Date Of Month")
    print("B- Weekday")
    print("C- Hour")
    o=input("Enter Choice: ")
    if o== 'A':
        hist(data3.dom,bins=30,rwidth=0.8,range=(0.5,30.5))
        xlabel('date of month')
        ylabel('frequency')
        title('Frequency by Date Of Month - uber trip august 2014')
    elif o=='B':
            hist(data3.weekday,bins=7,rwidth=0.8,range=(-.5,6))
            xticks (range(7),'mon tues wed thur fri sat sun'.split())
            xlabel('weekdays')
            ylabel('frequency')
            title('Frequency by Weekday - uber trip July 2014')
    elif o=='C':
                hist(data3.hour,bins=24,rwidth=0.8,range=(0.5,24.5))
                xlabel('hours')
                ylabel('frequency')
                title('Frequency by Hours - uber trip July 2014')
    else:
                    print("***Wrong Input***")
aug()

df3=pd.DataFrame(np.random.randint(1,540,4),index='week1 week2 week3 week4 '.split(),columns='Fare'.split())
print(df3)
print("Average fair for the month ")
print(df3.mean())
matplotlib.style.use('fast')
df3.plot.bar(figsize=(12,7),width=0.9,color='lightgreen',edgecolor='yellow',linewidth=1)        
title('Weekly income chart')
# Out:
# Uber Trip Data For Month July
# A- Date Of Month
# B- Weekday
# C- Hour
# Enter Choice: B
#        Fare
# week1   325
# week2   464
# week3   455
# week4   519
# Average fair for the month
# Fare    440.75
# dtype: float64
# Text(0.5, 1.0, 'Weekly income chart')

# %%
def hw():
    print("Hours and week analysis")
    c=input('enter your choice')
 
    if(c==1):
        aprilAn()
    elif(c==2):
        mayAn()
    elif(c==3):
        julyAn()
    elif(c==4):
        augAn()
    else:
        print("wrong choice")
hw()
# Out:
# Hours and week analysis
# enter your choice4
# wrong choice

# %%
def aprilAn():
        ch1=pd.DataFrame(np.random.randint(1,16,4),index='week1 week2 week3 week4'.split(),columns='hours'.split())
        print(ch1)
        matplotlib.style.use('fast')
        ch1.plot.bar(figsize(12,6),width=0.8,color='green',edgecolor='yellow',linewidth=1)
        xlabel('weeks')
        ylabel('hours')
        title('No. of hours working in a week')
aprilAn()
# Out:
#        hours
# week1     12
# week2      1
# week3      2
# week4     13

# %%
def mayAn():
    ch2=pd.DataFrame(np.random.randint(1,16,4),index='week1 week2 week3 week4'.split(),columns='hours'.split())
    print(ch2)
    matplotlib.style.use('dark_background')
    ch2.plot.bar(figsize(12,6),width=0.8,color='green',edgecolor='yellow',linewidth=1)
    ylabel('hours')
    title('No. of hours working in a week')
mayAn()
# Out:
#        hours
# week1      1
# week2      6
# week3     14
# week4     15

# %%
def julyAn():
    ch3=pd.DataFrame(np.random.randint(1,16,4),index='week1 week2 week3 week4'.split(),columns='hours'.split())
    print(ch3)
    matplotlib.style.use('dark_background')
    ch3.plot.bar(figsize(12,8),width=0.8,color='green',edgecolor='yellow',linewidth=1)
    xlabel('weeks')
    ylabel('hours')
    title('No. of hours working in a week')
julyAn()
# Out:
#        hours
# week1      5
# week2     15
# week3     11
# week4      5

# %%
def augAn():
    ch4=pd.DataFrame(np.random.randint(1,16,4),index='week1 week2 week3 week4'.split(),columns='hours'.split())
    print(ch4)
    matplotlib.style.use('dark_background')
    ch4.plot.bar(figsize(12,6),width=0.8,color='green',edgecolor='yellow',linewidth=1)
    xlabel('weeks')
    ylabel('hours')
    title('No. of hours working in a week')
augAn()
# Out:
#        hours
# week1     15
# week2     10
# week3     12
# week4      2

# %%
terminate=False
while not terminate:
    hw()
    response=input("would you like to enter again")
    if(response=='n'):
        terminate=True
